# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('Location.csv')
location_data = data.copy() # Creates a copy of the file.

# %%
location_data_series = location_data['Location'] # Converts to a pandas series for the purpose of the analysis.

# %%
location_data_series.head()
# Out:
# 0     Location 3
# 1     Location 6
# 2     Location 8
# 3    Location 26
# 4    Location 34
# Name: Location, dtype: object

# %%
type(location_data_series)
# Out:
# pandas.core.series.Series

# %%
location_data_series.describe()
# Out:
# count            1043
# unique            296
# top       Location 25
# freq               31
# Name: Location, dtype: object

# %%
len(location_data_series)
# Out:
# 1043

# %%
location_data_series.nunique()
# Out:
# 296

# %%
location_data_series.sort_values()
# Out:
# 637     Location 1
# 884     Location 1
# 465     Location 1
# 716    Location 10
# 623    Location 10
#           ...
# 482    Location 97
# 128    Location 97
# 669    Location 97
# 757    Location 98
# 372    Location 99
# Name: Location, Length: 1043, dtype: object

# %%
location_data_series.sort_values(ascending = True)
# Out:
# 637     Location 1
# 884     Location 1
# 465     Location 1
# 716    Location 10
# 623    Location 10
#           ...
# 482    Location 97
# 128    Location 97
# 669    Location 97
# 757    Location 98
# 372    Location 99
# Name: Location, Length: 1043, dtype: object

# %%
location_data_series.sort_values(ascending = False)
# Out:
# 372    Location 99
# 757    Location 98
# 128    Location 97
# 482    Location 97
# 271    Location 97
#           ...
# 202    Location 10
# 298    Location 10
# 637     Location 1
# 884     Location 1
# 465     Location 1
# Name: Location, Length: 1043, dtype: object

# %% [markdown]
# ##### Attributes and Method chaining

# %%
location_data_series.index
# Out:
# RangeIndex(start=0, stop=1043, step=1)

# %%
location_data_series.index.name = 'Index'

# %%
location_data_series
# Out:
# Index
# 0        Location 3
# 1        Location 6
# 2        Location 8
# 3       Location 26
# 4       Location 34
#            ...
# 1038    Location 73
# 1039    Location 82
# 1040    Location 11
# 1041    Location 26
# 1042    Location 94
# Name: Location, Length: 1043, dtype: object

# %%
location_data_series.sort_values().head()
# Out:
# Index
# 637     Location 1
# 884     Location 1
# 465     Location 1
# 716    Location 10
# 623    Location 10
# Name: Location, dtype: object
